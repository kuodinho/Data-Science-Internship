# %%
import pandas as pd
import geopandas as gpd
import osmnx as ox
import seaborn as sns

fig, ax = plt.subplots(figsize=(10,10))
df = pd.read_csv('listings_am.csv')
df['price_usd']=df.price.str.replace('[\$\,\.]','',regex=True).astype(int)/100
used_columns=df[['price_usd','longitude' ,'latitude',"neighbourhood_cleansed"]]
De_Baarsjes=used_columns[used_columns["neighbourhood_cleansed"]=="De Baarsjes - Oud-West"]
gdf = ox.geocode_to_gdf('Oud-West, Amsterdam').plot(color="lightblue", ax=ax)
g=sns.scatterplot(ax=ax, x='longitude',y='latitude',data=De_Baarsjes,hue='price_usd')
ax.set_title("Prices of properties in De Baarsjes - Oud-West neighbourhood")
plt.show()
